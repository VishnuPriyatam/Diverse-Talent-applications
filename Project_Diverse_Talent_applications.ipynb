# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
#read the file
df=pd.read_csv("/content/DiverseTalent_Applications.csv")

# %%
df
# Out:
#         Age             Gender         Region Educational_Background  \
# 0      32.0         Non-Binary           Asia            Mathematics
# 1      26.0         Non-Binary           Asia            Mathematics
# 2      35.0                NaN         Europe            Mathematics
# 3      28.0         Non-Binary         Europe            Mathematics
# 4      32.0         Non-Binary         Europe            Engineering
# ...     ...                ...            ...                    ...
# 10995  30.0               Male        Oceania            Mathematics
# 10996  28.0               Male            NaN       Computer Science
# 10997  22.0         Non-Binary  South America                    NaN
# 10998  26.0               Male  South America            Mathematics
# 10999  35.0  Prefer Not to Say  South America                    NaN
#
#       Technical_Skills  Experience_Level Preferred_Job_Role  \
# 0             Excel, R               1.0                NaN
# 1             R, Excel               0.0      Data Engineer
# 2      Python, Tableau               3.0     Data Architect
# 3             Excel, R               3.0       Data Analyst
# 4          Python, SQL               1.0      Data Engineer
# ...                ...               ...                ...
# 10995  Python, Tableau               1.0       Data Analyst
# 10996  Python, Tableau              10.0        ML Engineer
# 10997         R, Excel               1.0       Data Analyst
# 10998         R, Excel               3.0      Data Engineer
# 10999         R, Excel               NaN     Data Architect
#
#        Salary_Expectation  Application_Source Application_Status  \
# 0                65359.83     Company Website                NaN
# 1                68220.69            Referral                NaN
# 2                78471.71            LinkedIn                NaN
# 3                55964.86  Campus Recruitment                NaN
# 4                75208.78     Company Website                NaN
# ...                   ...                 ...                ...
# 10995            51351.38  Campus Recruitment                NaN
# 10996            85059.63     Company Website           Rejected
# 10997            51020.33            Referral           Rejected
# 10998            49287.02            Referral           Rejected
# 10999            71155.45          Job Portal            Pending
#
#        Interview_Score  Certifications_Count
# 0                 44.0                   5.0
# 1                 84.0                   4.0
# 2                 84.0                   5.0
# 3                 62.0                   0.0
# 4                 83.0                   1.0
# ...                ...                   ...
# 10995             68.0                   5.0
# 10996             79.0                   2.0
# 10997             83.0                   3.0
# 10998             70.0                   4.0
# 10999             99.0                   5.0
#
# [11000 rows x 12 columns]

# %%
#Q1: What are the first 5 rows of the dataset?
df.head(5)
# Out:
#     Age      Gender  Region Educational_Background Technical_Skills  \
# 0  32.0  Non-Binary    Asia            Mathematics         Excel, R
# 1  26.0  Non-Binary    Asia            Mathematics         R, Excel
# 2  35.0         NaN  Europe            Mathematics  Python, Tableau
# 3  28.0  Non-Binary  Europe            Mathematics         Excel, R
# 4  32.0  Non-Binary  Europe            Engineering      Python, SQL
#
#    Experience_Level Preferred_Job_Role  Salary_Expectation  \
# 0               1.0                NaN            65359.83
# 1               0.0      Data Engineer            68220.69
# 2               3.0     Data Architect            78471.71
# 3               3.0       Data Analyst            55964.86
# 4               1.0      Data Engineer            75208.78
#
#    Application_Source Application_Status  Interview_Score  \
# 0     Company Website                NaN             44.0
# 1            Referral                NaN             84.0
# 2            LinkedIn                NaN             84.0
# 3  Campus Recruitment                NaN             62.0
# 4     Company Website                NaN             83.0
#
#    Certifications_Count
# 0                   5.0
# 1                   4.0
# 2                   5.0
# 3                   0.0
# 4                   1.0

# %%
#Q2.What is the shape of the dataset?
df.shape
# Out:
# (11000, 12)

# %%
#Q3: What are the column names of the dataset?
df.columns
# Out:
# Index(['Age', 'Gender', 'Region', 'Educational_Background', 'Technical_Skills',
#        'Experience_Level', 'Preferred_Job_Role', 'Salary_Expectation',
#        'Application_Source', 'Application_Status', 'Interview_Score',
#        'Certifications_Count'],
#       dtype='object')

# %%
#Q4: What is the data type of each column?
df.dtypes
# Out:
# Age                       float64
# Gender                     object
# Region                     object
# Educational_Background     object
# Technical_Skills           object
# Experience_Level          float64
# Preferred_Job_Role         object
# Salary_Expectation        float64
# Application_Source         object
# Application_Status         object
# Interview_Score           float64
# Certifications_Count      float64
# dtype: object

# %%
#Q5: Are there any missing (null) values in the dataset?
df.isnull().sum()
# Out:
# Age                       1141
# Gender                    2199
# Region                    1589
# Educational_Background    1600
# Technical_Skills          1912
# Experience_Level          1406
# Preferred_Job_Role        1565
# Salary_Expectation           0
# Application_Source        1775
# Application_Status        2691
# Interview_Score            579
# Certifications_Count      1560
# dtype: int64

# %%
numerical_columns=df.select_dtypes(include=['int64','float64']).columns

# %%
numerical_columns
# Out:
# Index(['Age', 'Experience_Level', 'Salary_Expectation', 'Interview_Score',
#        'Certifications_Count'],
#       dtype='object')

# %%
categorical_columns=df.select_dtypes(exclude=['int64','float64']).columns

# %%
categorical_columns
# Out:
# Index(['Gender', 'Region', 'Educational_Background', 'Technical_Skills',
#        'Preferred_Job_Role', 'Application_Source', 'Application_Status'],
#       dtype='object')

# %%
#information of the dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     9859 non-null   float64
#  1   Gender                  8801 non-null   object
#  2   Region                  9411 non-null   object
#  3   Educational_Background  9400 non-null   object
#  4   Technical_Skills        9088 non-null   object
#  5   Experience_Level        9594 non-null   float64
#  6   Preferred_Job_Role      9435 non-null   object
#  7   Salary_Expectation      11000 non-null  float64
#  8   Application_Source      9225 non-null   object
#  9   Application_Status      8309 non-null   object
#  10  Interview_Score         10421 non-null  float64
#  11  Certifications_Count    9440 non-null   float64
# dtypes: float64(5), object(7)
# memory usage: 1.0+ MB

# %%
#Q6: What is the percentage of missing values for each column?
percentage_missing=df.isnull().sum()*100/len(df)
percentage_missing
# Out:
# Age                       10.372727
# Gender                    19.990909
# Region                    14.445455
# Educational_Background    14.545455
# Technical_Skills          17.381818
# Experience_Level          12.781818
# Preferred_Job_Role        14.227273
# Salary_Expectation         0.000000
# Application_Source        16.136364
# Application_Status        24.463636
# Interview_Score            5.263636
# Certifications_Count      14.181818
# dtype: float64

# %%
#Q7: What is the summary of the dataset?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     9859 non-null   float64
#  1   Gender                  8801 non-null   object
#  2   Region                  9411 non-null   object
#  3   Educational_Background  9400 non-null   object
#  4   Technical_Skills        9088 non-null   object
#  5   Experience_Level        9594 non-null   float64
#  6   Preferred_Job_Role      9435 non-null   object
#  7   Salary_Expectation      11000 non-null  float64
#  8   Application_Source      9225 non-null   object
#  9   Application_Status      8309 non-null   object
#  10  Interview_Score         10421 non-null  float64
#  11  Certifications_Count    9440 non-null   float64
# dtypes: float64(5), object(7)
# memory usage: 1.0+ MB

# %%
#Q8: What are the basic statistics of numerical columns?
df.describe()
# Out:
#                Age  Experience_Level  Salary_Expectation  Interview_Score  \
# count  9859.000000       9594.000000        11000.000000     10421.000000
# mean     28.535450          4.012612        70130.432006        70.043182
# std       6.064594          3.293133        15402.555208        15.925488
# min      20.000000          0.000000        14022.030000         3.000000
# 25%      24.000000          1.000000        59718.820000        53.000000
# 50%      28.000000          3.000000        70088.890000        70.000000
# 75%      32.000000          7.000000        80409.777500        83.000000
# max      40.000000         10.000000       300000.000000        99.000000
#
#        Certifications_Count
# count           9440.000000
# mean               2.517797
# std                1.715580
# min                0.000000
# 25%                1.000000
# 50%                3.000000
# 75%                4.000000
# max               12.000000

# %%
#Q9: What is the distribution of the 'Application_Status' column?
df['Application_Status'].value_counts()
# Out:
# Application_Status
# Accepted    2815
# Rejected    2758
# Pending     2736
# Name: count, dtype: int64

# %%
#Q10: What are the unique values in the 'Preferred_Job_Role' column?
df['Preferred_Job_Role'].unique()
# Out:
# array([nan, 'Data Engineer', 'Data Architect', 'Data Analyst',
#        'Data Scientist', 'BI Analyst', 'ML Engineer'], dtype=object)

# %%
#Q11: How many duplicate rows are present in the dataset?
df.duplicated().sum()
# Out:
# 1000

# %%
#Q12: Display the duplicate rows, if any.
df[df.duplicated()]
# Out:
#         Age             Gender         Region Educational_Background  \
# 10000  26.0         Non-Binary  North America             Statistics
# 10001  22.0         Non-Binary         Africa             Statistics
# 10002  28.0  Prefer Not to Say           Asia                    NaN
# 10003  35.0               Male        Oceania               Business
# 10004  24.0  Prefer Not to Say         Africa               Business
# ...     ...                ...            ...                    ...
# 10995  30.0               Male        Oceania            Mathematics
# 10996  28.0               Male            NaN       Computer Science
# 10997  22.0         Non-Binary  South America                    NaN
# 10998  26.0               Male  South America            Mathematics
# 10999  35.0  Prefer Not to Say  South America                    NaN
#
#       Technical_Skills  Experience_Level Preferred_Job_Role  \
# 10000         R, Excel              10.0        ML Engineer
# 10001      Python, SQL               3.0         BI Analyst
# 10002         Excel, R               5.0     Data Architect
# 10003      Python, SQL               7.0         BI Analyst
# 10004  Python, Tableau               2.0     Data Scientist
# ...                ...               ...                ...
# 10995  Python, Tableau               1.0       Data Analyst
# 10996  Python, Tableau              10.0        ML Engineer
# 10997         R, Excel               1.0       Data Analyst
# 10998         R, Excel               3.0      Data Engineer
# 10999         R, Excel               NaN     Data Architect
#
#        Salary_Expectation  Application_Source Application_Status  \
# 10000            80168.84            LinkedIn           Accepted
# 10001            54637.80          Job Portal                NaN
# 10002            89336.62            Referral                NaN
# 10003            86097.88                 NaN           Rejected
# 10004            96179.25  Campus Recruitment           Accepted
# ...                   ...                 ...                ...
# 10995            51351.38  Campus Recruitment                NaN
# 10996            85059.63     Company Website           Rejected
# 10997            51020.33            Referral           Rejected
# 10998            49287.02            Referral           Rejected
# 10999            71155.45          Job Portal            Pending
#
#        Interview_Score  Certifications_Count
# 10000             70.0                   2.0
# 10001             70.0                   NaN
# 10002             68.0                   5.0
# 10003             70.0                   5.0
# 10004             83.0                   NaN
# ...                ...                   ...
# 10995             68.0                   5.0
# 10996             79.0                   2.0
# 10997             83.0                   3.0
# 10998             70.0                   4.0
# 10999             99.0                   5.0
#
# [1000 rows x 12 columns]

# %%
#Q13: What is the distribution of the 'Gender' column?
df['Gender'].value_counts()
# Out:
# Gender
# Female               2284
# Male                 2204
# Prefer Not to Say    2199
# Non-Binary           2114
# Name: count, dtype: int64

# %%
#Q14: What are the unique values in the 'Educational_Background' column?
df['Educational_Background'].unique()
# Out:
# array(['Mathematics', 'Engineering', 'Business', 'Computer Science',
#        'Statistics', nan, 'Arts'], dtype=object)

# %%
#Q15: Visualize the distribution of 'Experience_Level'. (Countplot)
plt.figure(figsize = (10, 5))

sns.countplot(x = 'Experience_Level', data = df)

plt.title("Distribution of Experience Level")

plt.xlabel("Experience_Level")

plt.ylabel("Frequency")

plt.show()

# %%
#Q19: Visualize the distribution of 'Interview_Score'. (Histogram Plot)
sns.histplot(df.Interview_Score)
# Out:
# <Axes: xlabel='Interview_Score', ylabel='Count'>

# %%
#Q16: Visualize the distribution of 'Application_Status'. (Countplot)
plt.figure(figsize= (8,5))
sns.countplot(x = 'Application_Status' ,data=df)
plt.title('Distribution of Application Status')
plt.xlabel("Application_Status")
plt.ylabel("Frequency")
plt.show()

# %%
#Q17: Find the correlation between numerical columns.
correlation_matrix=df[numerical_columns].corr()
print(correlation_matrix)
# Out:
#                            Age  Experience_Level  Salary_Expectation  \
# Age                   1.000000          0.001425            0.007333
# Experience_Level      0.001425          1.000000           -0.002636
# Salary_Expectation    0.007333         -0.002636            1.000000
# Interview_Score      -0.005685         -0.009163           -0.016649
# Certifications_Count  0.009952          0.003525            0.015428
#
#                       Interview_Score  Certifications_Count
# Age                         -0.005685              0.009952
# Experience_Level            -0.009163              0.003525
# Salary_Expectation          -0.016649              0.015428
# Interview_Score              1.000000             -0.010684
# Certifications_Count        -0.010684              1.000000

# %%
#Q18: Visualize the correlation matrix using a heatmap.
plt.figure(figsize=(10,6))
sns.heatmap(correlation_matrix.corr(),annot=True)
# Out:
# <Axes: >

# %%
#Q19: Visualize the distribution of 'Interview_Score'. (Histogram Plot)
sns.histplot(df.Interview_Score)
# Out:
# <Axes: xlabel='Interview_Score', ylabel='Count'>

# %%
#Q20.Plot a box plot to identify extreme values in 'Salary_Expectation'.

sns.boxplot(df['Salary_Expectation'])
# Out:
# <Axes: ylabel='Salary_Expectation'>

# %%
#Q21: Create a new column 'High_Salary' where the value is 'Yes' if the 'Salary_Expectation' is above 100,000, otherwise 'No'.

df['High_Salary']=np.where(df['Salary_Expectation']<=100000,"Yes","No")
df['High_Salary'].value_counts()
# Out:
# High_Salary
# Yes    10754
# No       246
# Name: count, dtype: int64

# %%
df['High_Salary']
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#          ..
# 10995    No
# 10996    No
# 10997    No
# 10998    No
# 10999    No
# Name: High_Salary, Length: 11000, dtype: object

# %%
df['High_Salary'].value_counts()
# Out:
# High_Salary
# Yes    10754
# No       246
# Name: count, dtype: int64

# %%
#Q22: Create a column 'Experienced' with value 'Yes' if 'Experience_Level' is 'Senior', otherwise 'No'.

df['Experienced']=np.where(df['Experience_Level']<=2,"Fresher",
                  np.where(df['Experience_Level']<=5,"Mid-level",
                  np.where(df['Experience_Level']<=8,"Senior",
                  np.where(df['Experience_Level']<=10,"Super-Senior","Super super senior"))))

# %%
df['Experienced']
# Out:
# 0                   Fresher
# 1                   Fresher
# 2                 Mid-level
# 3                 Mid-level
# 4                   Fresher
#                 ...
# 10995               Fresher
# 10996          Super-Senior
# 10997               Fresher
# 10998             Mid-level
# 10999    Super super senior
# Name: Experienced, Length: 11000, dtype: object

# %%
df['Experienced']=np.where(df['Experience_level']=="Senior","Yes","No")
df['Experienced'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Experience_level'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-d0f1ba4abd64> in <cell line: 0>()
# ----> 1 df['Experienced']=np.where(df['Experience_level']=="Senior","Yes","No")
#       2 df['Experienced'].value_counts()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Experience_level'

# %%
df.shape
# Out:
# (11000, 14)

# %%
#Q23: Create a column 'Good_Score' where the value is 'Yes' if 'Interview_Score' is above 80, otherwise 'No'.

df['Good_Score']=np.where(df['Interview_Score']==80,"Yes","No")

# %%
df['Good_Score']
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#          ..
# 10995    No
# 10996    No
# 10997    No
# 10998    No
# 10999    No
# Name: Good_Score, Length: 11000, dtype: object

# %%
df['Good_Score'].value_counts()
# Out:
# Good_Score
# No    11000
# Name: count, dtype: int64

# %%
#Q24: Create a column 'Certified' where the value is 'Yes' if 'Certifications_Count' is 2 or more, otherwise 'No'.

df['Certified']=np.where(df['Certifications_Count']<=2,"Yes","No")

# %%
df['Certified']
# Out:
# 0         No
# 1         No
# 2         No
# 3        Yes
# 4        Yes
#         ...
# 10995     No
# 10996    Yes
# 10997     No
# 10998     No
# 10999     No
# Name: Certified, Length: 11000, dtype: object

# %%
df['Certified'].value_counts()
# Out:
# Certified
# No     6313
# Yes    4687
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (11000, 16)

# %%
#Q25: Create a column 'Technical_Background' where the value is 'Yes' if 'Educational_Background' is 'Computer Science' or 'Information Technology'. Otherwise, 'No'.

df['Techanical_Background']=np.where(df['Educational_Background']=="Computer Science","Yes" or "Information Technology","No")

# %%
df['Techanical_Background']
# Out:
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#         ...
# 10995     No
# 10996    Yes
# 10997     No
# 10998     No
# 10999     No
# Name: Techanical_Background, Length: 11000, dtype: object

# %%
df['Techanical_Background'].value_counts()
# Out:
# Techanical_Background
# No     9455
# Yes    1545
# Name: count, dtype: int64
